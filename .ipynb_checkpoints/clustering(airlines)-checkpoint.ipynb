# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

import warnings
warnings.filterwarnings('ignore')

# %%
import scipy.cluster.hierarchy as sch
from sklearn.cluster import AgglomerativeClustering

# %%
airlines_data = pd.read_excel('EastWestAirlines.xlsx',1)
airlines_data
# Out:
#        ID#  Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 0        1    28143           0          1          1          1          174
# 1        2    19244           0          1          1          1          215
# 2        3    41354           0          1          1          1         4123
# 3        4    14776           0          1          1          1          500
# 4        5    97752           0          4          1          1        43300
# ...    ...      ...         ...        ...        ...        ...          ...
# 3994  4017    18476           0          1          1          1         8525
# 3995  4018    64385           0          1          1          1          981
# 3996  4019    73597           0          3          1          1        25447
# 3997  4020    54899           0          1          1          1          500
# 3998  4021     3016           0          1          1          1            0
#
# ...

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
scaler = MinMaxScaler()
scaled_data = scaler.fit_transform(airlines_data)

# %%
columns = airlines_data.columns

# %%
scaled_df = pd.DataFrame(data=scaled_data,columns=columns)
scaled_df
# Out:
#            ID#   Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  \
# 0     0.000000  0.016508         0.0       0.00        0.0        0.0
# 1     0.000249  0.011288         0.0       0.00        0.0        0.0
# 2     0.000498  0.024257         0.0       0.00        0.0        0.0
# 3     0.000746  0.008667         0.0       0.00        0.0        0.0
# 4     0.000995  0.057338         0.0       0.75        0.0        0.0
# ...        ...       ...         ...        ...        ...        ...
# 3994  0.999005  0.010837         0.0       0.00        0.0        0.0
# 3995  0.999254  0.037766         0.0       0.00        0.0        0.0
# 3996  0.999502  0.043169         0.0       0.50        0.0        0.0
# 3997  0.999751  0.032202         0.0       0.00        0.0        0.0
# 3998  1.000000  0.001769         0.0       0.00        0.0        0.0
#
#       Bonus_miles  Bonus_trans  Flight_miles_12mo  Flight_trans_12  \
# ...

# %%
dendrogram = sch.dendrogram(sch.linkage(scaled_df, method='complete'))

# %%
hc = AgglomerativeClustering(n_clusters=4, affinity = 'euclidean', linkage = 'complete')
hc
# Out:
# AgglomerativeClustering(linkage='complete', n_clusters=4)

# %%
y_hc = hc.fit_predict(scaled_df)
y_hc
# Out:
# array([1, 1, 1, ..., 0, 1, 1], dtype=int64)

# %%
Clusters=pd.DataFrame(y_hc,columns=['Clusters'])
Clusters
# Out:
#       Clusters
# 0            1
# 1            1
# 2            1
# 3            1
# 4            0
# ...        ...
# 3994         0
# 3995         0
# 3996         0
# 3997         1
# 3998         1
#
# [3999 rows x 1 columns]

# %%
airlines_data1 = airlines_data.copy()
airlines_data1['clusters'] = Clusters

# %%
airlines_data1
# Out:
#        ID#  Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 0        1    28143           0          1          1          1          174
# 1        2    19244           0          1          1          1          215
# 2        3    41354           0          1          1          1         4123
# 3        4    14776           0          1          1          1          500
# 4        5    97752           0          4          1          1        43300
# ...    ...      ...         ...        ...        ...        ...          ...
# 3994  4017    18476           0          1          1          1         8525
# 3995  4018    64385           0          1          1          1          981
# 3996  4019    73597           0          3          1          1        25447
# 3997  4020    54899           0          1          1          1          500
# 3998  4021     3016           0          1          1          1            0
#
# ...

# %%
airlines_data1[airlines_data1['clusters'] == 0]
# Out:
#        ID#  Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 4        5    97752           0          4          1          1        43300
# 7        8    20856           0          1          1          1         5250
# 8        9   443003           0          3          2          1         1753
# 9       10   104860           0          3          1          1        28426
# 11      12    96522           0          5          1          1        61105
# ...    ...      ...         ...        ...        ...        ...          ...
# 3987  4010    11933           0          1          1          1          249
# 3989  4012     2622           0          1          1          1         1625
# 3994  4017    18476           0          1          1          1         8525
# 3995  4018    64385           0          1          1          1          981
# 3996  4019    73597           0          3          1          1        25447
#
# ...

# %%
airlines_data1[airlines_data1['clusters'] == 1]
# Out:
#        ID#  Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 0        1    28143           0          1          1          1          174
# 1        2    19244           0          1          1          1          215
# 2        3    41354           0          1          1          1         4123
# 3        4    14776           0          1          1          1          500
# 5        6    16420           0          1          1          1            0
# ...    ...      ...         ...        ...        ...        ...          ...
# 3991  4014    39142           0          3          1          1        14981
# 3992  4015    11181           0          1          1          1          929
# 3993  4016     3974           0          1          1          1          365
# 3997  4020    54899           0          1          1          1          500
# 3998  4021     3016           0          1          1          1            0
#
# ...

# %%
airlines_data1[airlines_data1['clusters'] == 2]
# Out:
#        ID#  Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 2015  2032    53232         888          4          1          1        80696
# 3235  3257   287033           0          1          1          1        26161
# 3583  3606   160114         500          1          1          1        71954
# 3594  3617    27619           0          4          1          1        83726
#
#       Bonus_trans  Flight_miles_12mo  Flight_trans_12  Days_since_enroll  \
# 2015           65              22100               45               3831
# 3235           58              12873               53               2272
# 3583           86              30817               53               1373
# 3594           68              14050               46               1325
#
#       Award?  clusters
# 2015       1         2
# 3235       1         2
# 3583       1         2
# 3594       1         2

# %%
airlines_data1[airlines_data1['clusters'] == 3]
# Out:
#        ID#  Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 198    202     8669           0          1          3          1        11397
# 226    230   117329           0          1          2          1         6448
# 381    386   167670           0          1          3          1        15907
# 392    398    11189           0          1          2          1         9044
# 561    568   380930           0          2          2          1        22485
# 794    804    55610           0          1          2          1         5095
# 940    951    44824           0          1          3          1        21107
# 1149  1161    84856           0          1          2          1         6894
# 1270  1283    16103           0          1          3          1        10819
# 1383  1397    18154           0          1          2          1         7748
# 1389  1403    49145           0          1          2          1        12755
# ...

# %%
wcss = []
for i in range(1, 11):
    kmeans = KMeans(n_clusters=i,random_state=0)
    kmeans.fit(scaled_df)
    wcss.append(kmeans.inertia_) 
    print(i,wcss)

plt.plot(range(1, 11), wcss)
plt.title('Elbow Method')
plt.xlabel('Number of clusters')
plt.ylabel('WCSS')
plt.show()
# Out:
# 1 [2164.1265977775024]
# 2 [2164.1265977775024, 1146.4595170935336]
# 3 [2164.1265977775024, 1146.4595170935336, 865.2605940455062]
# 4 [2164.1265977775024, 1146.4595170935336, 865.2605940455062, 673.4712187348898]
# 5 [2164.1265977775024, 1146.4595170935336, 865.2605940455062, 673.4712187348898, 536.2034790432651]
# 6 [2164.1265977775024, 1146.4595170935336, 865.2605940455062, 673.4712187348898, 536.2034790432651, 452.228430507411]
# 7 [2164.1265977775024, 1146.4595170935336, 865.2605940455062, 673.4712187348898, 536.2034790432651, 452.228430507411, 397.9445893438363]
# 8 [2164.1265977775024, 1146.4595170935336, 865.2605940455062, 673.4712187348898, 536.2034790432651, 452.228430507411, 397.9445893438363, 346.2280906369076]
# 9 [2164.1265977775024, 1146.4595170935336, 865.2605940455062, 673.4712187348898, 536.2034790432651, 452.228430507411, 397.9445893438363, 346.2280906369076, 308.51695820798795]
# ...

# %%
from sklearn.cluster import KMeans

# %%
kmeans_cluster = KMeans(n_clusters=2)
kmeans_cluster.fit(scaled_df)
pred = kmeans_cluster.predict(scaled_df)

# %%
pred
# Out:
# array([0, 0, 0, ..., 1, 0, 0])

# %%
clusters_kmeans=pd.DataFrame(pred,columns=['Clusters'])
clusters_kmeans
# Out:
#       Clusters
# 0            0
# 1            0
# 2            0
# 3            0
# 4            1
# ...        ...
# 3994         1
# 3995         1
# 3996         1
# 3997         0
# 3998         0
#
# [3999 rows x 1 columns]

# %%
airlines_data2= airlines_data.copy()
airlines_data2['clusters'] = clusters_kmeans

# %%
airlines_data2
# Out:
#        ID#  Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 0        1    28143           0          1          1          1          174
# 1        2    19244           0          1          1          1          215
# 2        3    41354           0          1          1          1         4123
# 3        4    14776           0          1          1          1          500
# 4        5    97752           0          4          1          1        43300
# ...    ...      ...         ...        ...        ...        ...          ...
# 3994  4017    18476           0          1          1          1         8525
# 3995  4018    64385           0          1          1          1          981
# 3996  4019    73597           0          3          1          1        25447
# 3997  4020    54899           0          1          1          1          500
# 3998  4021     3016           0          1          1          1            0
#
# ...

# %%
airlines_data2[airlines_data2['clusters'] == 0]
# Out:
#        ID#  Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 0        1    28143           0          1          1          1          174
# 1        2    19244           0          1          1          1          215
# 2        3    41354           0          1          1          1         4123
# 3        4    14776           0          1          1          1          500
# 5        6    16420           0          1          1          1            0
# ...    ...      ...         ...        ...        ...        ...          ...
# 3991  4014    39142           0          3          1          1        14981
# 3992  4015    11181           0          1          1          1          929
# 3993  4016     3974           0          1          1          1          365
# 3997  4020    54899           0          1          1          1          500
# 3998  4021     3016           0          1          1          1            0
#
# ...

# %%
airlines_data2[airlines_data2['clusters'] == 1]
# Out:
#        ID#  Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 4        5    97752           0          4          1          1        43300
# 7        8    20856           0          1          1          1         5250
# 8        9   443003           0          3          2          1         1753
# 9       10   104860           0          3          1          1        28426
# 11      12    96522           0          5          1          1        61105
# ...    ...      ...         ...        ...        ...        ...          ...
# 3987  4010    11933           0          1          1          1          249
# 3989  4012     2622           0          1          1          1         1625
# 3994  4017    18476           0          1          1          1         8525
# 3995  4018    64385           0          1          1          1          981
# 3996  4019    73597           0          3          1          1        25447
#
# ...

# %%
from sklearn.cluster import DBSCAN
dbs = DBSCAN(eps=0.3, min_samples=3)
dbs.fit(scaled_df)
# Out:
# DBSCAN(eps=0.3, min_samples=3)

# %%
dbs_clusters = dbs.labels_
dbs_clusters
# Out:
# array([0, 0, 0, ..., 1, 0, 0], dtype=int64)

# %%
airlines_data3 = airlines_data.copy()

# %%
airlines_data3['dbs_clusters'] = dbs_clusters

# %%
airlines_data3
# Out:
#        ID#  Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 0        1    28143           0          1          1          1          174
# 1        2    19244           0          1          1          1          215
# 2        3    41354           0          1          1          1         4123
# 3        4    14776           0          1          1          1          500
# 4        5    97752           0          4          1          1        43300
# ...    ...      ...         ...        ...        ...        ...          ...
# 3994  4017    18476           0          1          1          1         8525
# 3995  4018    64385           0          1          1          1          981
# 3996  4019    73597           0          3          1          1        25447
# 3997  4020    54899           0          1          1          1          500
# 3998  4021     3016           0          1          1          1            0
#
# ...

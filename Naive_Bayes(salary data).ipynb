# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix,classification_report,roc_curve,roc_auc_score

import warnings
warnings.filterwarnings('ignore')

# %%
salary_train_data = pd.read_csv('SalaryData_Train(1).csv')
salary_train_data
# Out:
#        age          workclass    education  educationno        maritalstatus  \
# 0       39          State-gov    Bachelors           13        Never-married
# 1       50   Self-emp-not-inc    Bachelors           13   Married-civ-spouse
# 2       38            Private      HS-grad            9             Divorced
# 3       53            Private         11th            7   Married-civ-spouse
# 4       28            Private    Bachelors           13   Married-civ-spouse
# ...    ...                ...          ...          ...                  ...
# 30156   27            Private   Assoc-acdm           12   Married-civ-spouse
# 30157   40            Private      HS-grad            9   Married-civ-spouse
# 30158   58            Private      HS-grad            9              Widowed
# 30159   22            Private      HS-grad            9        Never-married
# 30160   52       Self-emp-inc      HS-grad            9   Married-civ-spouse
#
# ...

# %%
salary_test_data = pd.read_csv('SalaryData_Test(1).csv')
salary_test_data
# Out:
#        age      workclass      education  educationno        maritalstatus  \
# 0       25        Private           11th            7        Never-married
# 1       38        Private        HS-grad            9   Married-civ-spouse
# 2       28      Local-gov     Assoc-acdm           12   Married-civ-spouse
# 3       44        Private   Some-college           10   Married-civ-spouse
# 4       34        Private           10th            6        Never-married
# ...    ...            ...            ...          ...                  ...
# 15055   33        Private      Bachelors           13        Never-married
# 15056   39        Private      Bachelors           13             Divorced
# 15057   38        Private      Bachelors           13   Married-civ-spouse
# 15058   44        Private      Bachelors           13             Divorced
# 15059   35   Self-emp-inc      Bachelors           13   Married-civ-spouse
#
# ...

# %%
salary_train_data.isna().sum()
# Out:
# age              0
# workclass        0
# education        0
# educationno      0
# maritalstatus    0
# occupation       0
# relationship     0
# race             0
# sex              0
# capitalgain      0
# capitalloss      0
# hoursperweek     0
# native           0
# Salary           0
# dtype: int64

# %%
salary_test_data.isna().sum()
# Out:
# age              0
# workclass        0
# education        0
# educationno      0
# maritalstatus    0
# occupation       0
# relationship     0
# race             0
# sex              0
# capitalgain      0
# capitalloss      0
# hoursperweek     0
# native           0
# Salary           0
# dtype: int64

# %%
salary_train_data.dtypes
# Out:
# age               int64
# workclass        object
# education        object
# educationno       int64
# maritalstatus    object
# occupation       object
# relationship     object
# race             object
# sex              object
# capitalgain       int64
# capitalloss       int64
# hoursperweek      int64
# native           object
# Salary           object
# dtype: object

# %%
salary_test_data.dtypes
# Out:
# age               int64
# workclass        object
# education        object
# educationno       int64
# maritalstatus    object
# occupation       object
# relationship     object
# race             object
# sex              object
# capitalgain       int64
# capitalloss       int64
# hoursperweek      int64
# native           object
# Salary           object
# dtype: object

# %% [markdown]
# ### Data Preprocessing

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()

# %%
categorical = ['workclass','education','maritalstatus','occupation','relationship','race','sex','native','Salary']

# %%
for i in categorical:
    salary_train_data[i]= le.fit_transform(salary_train_data[i])
    salary_test_data[i]=le.fit_transform(salary_test_data[i])

# %%
salary_train_data
# Out:
#        age  workclass  education  educationno  maritalstatus  occupation  \
# 0       39          5          9           13              4           0
# 1       50          4          9           13              2           3
# 2       38          2         11            9              0           5
# 3       53          2          1            7              2           5
# 4       28          2          9           13              2           9
# ...    ...        ...        ...          ...            ...         ...
# 30156   27          2          7           12              2          12
# 30157   40          2         11            9              2           6
# 30158   58          2         11            9              6           0
# 30159   22          2         11            9              4           0
# 30160   52          3         11            9              2           3
#
#        relationship  race  sex  capitalgain  capitalloss  hoursperweek  \
# ...

# %%
salary_test_data
# Out:
#        age  workclass  education  educationno  maritalstatus  occupation  \
# 0       25          2          1            7              4           6
# 1       38          2         11            9              2           4
# 2       28          1          7           12              2          10
# 3       44          2         15           10              2           6
# 4       34          2          0            6              4           7
# ...    ...        ...        ...          ...            ...         ...
# 15055   33          2          9           13              4           9
# 15056   39          2          9           13              0           9
# 15057   38          2          9           13              2           9
# 15058   44          2          9           13              0           0
# 15059   35          3          9           13              2           3
#
#        relationship  race  sex  capitalgain  capitalloss  hoursperweek  \
# ...

# %%
salary_train_data.describe().T
# Out:
#                  count         mean          std   min   25%   50%   75%  \
# age            30161.0    38.438115    13.134830  17.0  28.0  37.0  47.0
# workclass      30161.0     2.199330     0.953940   0.0   2.0   2.0   2.0
# education      30161.0    10.333610     3.812260   0.0   9.0  11.0  12.0
# educationno    30161.0    10.121316     2.550037   1.0   9.0  10.0  13.0
# maritalstatus  30161.0     2.580087     1.498018   0.0   2.0   2.0   4.0
# occupation     30161.0     5.959849     4.029633   0.0   2.0   6.0   9.0
# relationship   30161.0     1.418322     1.601361   0.0   0.0   1.0   3.0
# race           30161.0     3.678592     0.834721   0.0   4.0   4.0   4.0
# sex            30161.0     0.675707     0.468118   0.0   0.0   1.0   1.0
# capitalgain    30161.0  1092.044064  7406.466611   0.0   0.0   0.0   0.0
# capitalloss    30161.0    88.302311   404.121321   0.0   0.0   0.0   0.0
# hoursperweek   30161.0    40.931269    11.980182   1.0  40.0  40.0  45.0
# ...

# %% [markdown]
# ### Data Visualisation

# %%
def count_plot(salary_train_data, columns):
    plt.figure(figsize=(15, 10))
    for indx, var  in enumerate(columns):
        plt.subplot(5,3 , indx+1)
        g = sns.countplot(salary_train_data[var], hue= salary_train_data['Salary'])
    plt.tight_layout()
features = salary_train_data.columns.tolist()
features.remove('Salary')
features
# Out:
# ['age',
#  'workclass',
#  'education',
#  'educationno',
#  'maritalstatus',
#  'occupation',
#  'relationship',
#  'race',
#  'sex',
#  'capitalgain',
#  'capitalloss',
#  'hoursperweek',
#  'native']

# %%
count_plot(salary_train_data,features)

# %%
from sklearn.naive_bayes import GaussianNB,MultinomialNB

# %%
x_train=salary_train_data.drop(labels='Salary',axis=1)
y_train=salary_train_data['Salary']

# %%
x_test = salary_test_data.drop(labels='Salary',axis=1)
y_test = salary_test_data['Salary']

# %%
gb_model=GaussianNB().fit(x_train,y_train)

# %%
y_pred=gb_model.predict(x_test)

# %%
confu_matrix = confusion_matrix(y_test,y_pred)
sns.heatmap(data=confu_matrix,annot=True,fmt='g')
# Out:
# <AxesSubplot:>

# %%
print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.81      0.95      0.87     11360
#            1       0.67      0.33      0.44      3700
#
#     accuracy                           0.79     15060
#    macro avg       0.74      0.64      0.66     15060
# weighted avg       0.78      0.79      0.77     15060

# %%
fpr, tpr, thresholds = roc_curve(y_train, gb_model.predict_proba (x_train)[:,1])

auc = roc_auc_score(y_test,y_pred)
print(auc)

import matplotlib.pyplot as plt
plt.plot(fpr, tpr, color='red', label='logit model ( area  = %0.2f)'%auc)
plt.plot([0, 1], [0, 1], 'k--')
plt.xlabel('False Positive Rate or [1 - True Negative Rate]')
plt.ylabel('True Positive Rate')
plt.show()
# Out:
# 0.636925913589646

# %%
mb_model=MultinomialNB().fit(x_train,y_train)

# %%
y_pred=mb_model.predict(x_test)

# %%
confu_matrix_mb = confusion_matrix(y_test,y_pred)
sns.heatmap(data=confu_matrix_mb,annot=True,fmt='g')
# Out:
# <AxesSubplot:>

# %%
print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.79      0.96      0.87     11360
#            1       0.62      0.21      0.32      3700
#
#     accuracy                           0.77     15060
#    macro avg       0.71      0.58      0.59     15060
# weighted avg       0.75      0.77      0.73     15060

# %%
fpr, tpr, thresholds = roc_curve(y_train, mb_model.predict_proba (x_train)[:,1])

auc = roc_auc_score(y_test,y_pred)
print(auc)

import matplotlib.pyplot as plt
plt.plot(fpr, tpr, color='red', label='logit model ( area  = %0.2f)'%auc)
plt.plot([0, 1], [0, 1], 'k--')
plt.xlabel('False Positive Rate or [1 - True Negative Rate]')
plt.ylabel('True Positive Rate')
plt.show()
# Out:
# 0.5847627997716026

# %% [markdown]
# #### Inference
#     Gaussian model has better performance than MultinomialnB
